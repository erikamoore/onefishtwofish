# %% [markdown]
# ### main processing loop for total dist traveled by the fish :)
# (also includes fish body size estimation)
#
#
# **See `fish_utils.py` for source code.**

# %%
# general imports
import pandas as pd
import numpy as np
import matplotlib.gridspec as gridspec
from tqdm.notebook import tqdm as tqdm


# local imports
import fish_utils as fi 
import visuals as vi
from constants import *
parts
edges
# Out:
# c:\Users\erika\miniconda3\envs\fish\python.exe
# 2.2.3
# [('L_eye', 'mouth'),
#  ('R_eye', 'mouth'),
#  ('L_eye', 'spine'),
#  ('R_eye', 'spine'),
#  ('spine', 'tail')]

# %%
from pathlib import Path
file_paths = [str(file) for file in Path("allcsvs").rglob("*.csv")]
file_paths = sorted(file_paths, key=lambda x: ["ones", "twos", "threes", "fours"].index(Path(x).parts[-2]))

# %%
results = []
# for file_path in tqdm(file_paths, desc="Processing files"):
for file_path in file_paths:
    print(f"\nProcessing file: {file_path}")
    df = fi.load_and_preprocess_data(filepath=file_path, center_method='least_squares', interpolate=True)

    # we find out what the group name and group size are
    group_name = Path(file_path).stem  # ex extracts "t1_4s" from "allcsvs/fours/t1_4s.csv"

    group_size = int(group_name.split('_')[1][0])
    # account for potential mislabellings


    # and generate list of track ids
    track_ids = [f"track_{i}" for i in range(group_size)]

    # calc total distance for each track
    distance_df = fi.calc_total_distance_traveled(df, track_ids)
    distance_df['group_id'] = group_name
    distance_df['group_size'] = group_size
    distance_df['fish_id'] = distance_df['group_id'] + "_" + distance_df['track']

    # we can also estimate fish sizes for each track
    size_df= fi.estimate_fish_sizes(df, parts, edges)
    print(type(size_df))
    print(size_df.columns)
    size_df.rename(columns={'average_length': 'estimated_size'}, inplace=True)

    # merging estimated sizes with distance_df
    distance_df = distance_df.merge(size_df[['track', 'estimated_size']], on='track', how='left')

    # reordering columns for personal preference
    distance_df = distance_df[['fish_id', 'group_size', 'group_id', 'track', 'total_distance', 'estimated_size']]
    results.append(distance_df)


distance_results_df1 = pd.concat(results, ignore_index=True)
print("\nTotal dist traveled and estimated size for each track:")
print(distance_results_df1)

# get a csv
distance_results_df1.to_csv("total_dists_with_sizes_.csv", index=False)
# Out:
# Processing file: allcsvs\ones\t1_1s.csv
# Calculating total distance for each track:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35991, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.865066  771.956665  868.957458     0.977134
# 1          1  track_0        0.874235  771.884583  868.931885     0.979783
# 2          2  track_0        0.875761  771.909485  868.926147     0.982751
# 3          3  track_0        0.874711  771.904785  868.932861     0.982176
# 4          4  track_0        0.874979  771.916382  868.923340     0.981547
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  796.241821  868.879883     0.971936  787.783386  ...    402.936617
# 1  796.215698  868.848389     0.974860  787.802063  ...    402.895699
# 2  796.259888  868.809143     0.976705  787.828369  ...    402.902429
# 3  796.243347  868.813599     0.974248  787.819336  ...    402.907530
# 4  796.277527  868.814697     0.975345  787.835693  ...    402.918082
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0    -0.938801  346.159115  276.309753   442.914453   -0.673652   294.297115
# 1    -0.938669  346.204891  276.298278   442.943072   -0.673567   294.332882
# 2    -0.938600  346.204708  276.291076   442.938437   -0.673555   294.342709
# 3    -0.938638  346.188473  276.288025   442.923844   -0.673573   294.331539
# 4    -0.938606  346.191769  276.304992   442.937004   -0.673598   294.345944
#
#    spine_adj_y  spine_radius  spine_theta
# 0   308.747558    426.539385    -0.809356
# 1   308.709778    426.536718    -0.809234
# 2   308.694214    426.532235    -0.809192
# 3   308.700256    426.528901    -0.809221
# 4   308.705688    426.542772    -0.809205
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[ 222.21044546,  344.67504852],
#        [ 222.13836294,  344.64947479],
#        [ 222.16326528,  344.64373748],
#        ...,
#        [ 378.99035269, -111.89294465],
#        [ 379.00866323, -111.87088044],
#        [ 378.9976769 , -111.88858063]], shape=(35991, 2)), 'L_eye': array([[246.49560171, 344.59747283],
#        [246.46947866, 344.56597869],
#        [246.51366812, 344.52673309],
#        ...,
#        [378.78112417, -84.63421662],
#        [378.79430776, -84.61660798],
#        [378.78637319, -84.63620026]], shape=(35991, 2)), 'R_eye': array([[238.03716665, 325.10955779],
#        [238.05584341, 325.0451657 ],
#        [238.08214956, 325.03424041],
#        ...,
#        [398.36681753, -95.76120026],
#        [398.37316519, -95.73635895],
#        [398.36895376, -95.75369294]], shape=(35991, 2)), 'spine': array([[294.29711538, 308.74755828],
#        [294.33288198, 308.70977752],
#        [294.34270864, 308.69421356],
#        ...,
#        [410.63634878, -32.37646516],
#        [410.64233022, -32.34497102],
#        [410.6438561 , -32.36819489]], shape=(35991, 2)), 'tail': array([[346.15911489, 276.30975311],
#        [346.20489126, 276.2982785 ],
#        [346.20470815, 276.29107635],
#        ...,
#        [426.22729116,  23.84551971],
#        [426.2242394 ,  23.87561004],
#        [426.21593862,  23.83746307]], shape=(35991, 2))}
#   mouth: (35991, 2), first three rows (i.e., frames): [[222.21044546 344.67504852]
#  [222.13836294 344.64947479]
#  [222.16326528 344.64373748]]
#   L_eye: (35991, 2), first three rows (i.e., frames): [[246.49560171 344.59747283]
#  [246.46947866 344.56597869]
#  [246.51366812 344.52673309]]
#   R_eye: (35991, 2), first three rows (i.e., frames): [[238.03716665 325.10955779]
#  [238.05584341 325.0451657 ]
#  [238.08214956 325.03424041]]
#   spine: (35991, 2), first three rows (i.e., frames): [[294.29711538 308.74755828]
#  [294.33288198 308.70977752]
#  [294.34270864 308.69421356]]
#   tail: (35991, 2), first three rows (i.e., frames): [[346.15911489 276.30975311]
#  [346.20489126 276.2982785 ]
#  [346.20470815 276.29107635]]
#
#  track_data length is 35991
#   first 5 lengths for track track_0: [np.float64(228.9635853247188), np.float64(229.15368840998548), np.float64(229.10887352535258), np.float64(229.09322240953435), np.float64(229.07346987099572)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\ones\t2_1s.csv
# Calculating total distance for each track:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35993, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.828559  201.057175  725.383789     1.067762
# 1          1  track_0        0.827919  201.071503  725.413147     1.068558
# 2          2  track_0        0.834698  201.052200  725.356934     1.074175
# 3          3  track_0        0.833557  201.062073  725.365112     1.071873
# 4          4  track_0        0.833018  201.042389  725.348267     1.071976
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  196.815384  708.901917     1.003493  185.196182  ...    412.517095
# 1  196.831665  708.931702     1.004122  185.208893  ...    412.519403
# 2  196.809570  708.905884     0.999412  185.187454  ...    412.525865
# 3  196.821091  708.908447     0.999195  185.201920  ...    412.516995
# 4  196.811722  708.901733     1.000877  185.198166  ...    412.511628
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0    -2.654551 -412.343967  116.704895   428.541223   -2.865778  -384.988895
# 1    -2.654474 -412.331303  116.752136   428.541905   -2.865664  -384.970737
# 2    -2.654556 -412.387669  116.689270   428.579018   -2.865841  -385.020969
# 3    -2.654521 -412.386539  116.685119   428.576802   -2.865850  -385.005390
# 4    -2.654565 -412.401157  116.677673   428.588840   -2.865876  -385.008442
#
#    spine_adj_y  spine_radius  spine_theta
# 0   156.397278    415.543690    -2.755720
# 1   156.438232    415.542283    -2.755612
# 2   156.365905    415.561600    -2.755819
# 3   156.372375    415.549600    -2.755790
# 4   156.357971    415.547007    -2.755825
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[-348.6890449 ,  201.10137908],
#        [-348.67471689,  201.13073699],
#        [-348.69401926,  201.07452361],
#        ...,
#        [-380.73007578,  156.52117889],
#        [-380.73859019,  156.5250241 ],
#        [-380.73137278,  156.54461639]], shape=(35993, 2)), 'L_eye': array([[-352.93083567,  184.61950652],
#        [-352.91455454,  184.64929168],
#        [-352.93664927,  184.62347381],
#        ...,
#        [-380.78274912,  140.11358611],
#        [-380.78467173,  140.10784881],
#        [-380.77737803,  140.11675994]], shape=(35993, 2)), 'R_eye': array([[-364.55003733,  193.06378143],
#        [-364.53732676,  193.09271209],
#        [-364.55876536,  193.06603973],
#        ...,
#        [-393.03235239,  147.6076657 ],
#        [-393.02624888,  147.61248748],
#        [-393.01773447,  147.62390106]], shape=(35993, 2)), 'spine': array([[-384.98889536,  156.39727752],
#        [-384.9707374 ,  156.43823211],
#        [-385.02096934,  156.36590545],
#        ...,
#        [-405.49800486,  104.03930633],
#        [-405.50461191,  104.04339568],
#        [-405.50345225,  104.05676238]], shape=(35993, 2)), 'tail': array([[-412.34396738,  116.70489471],
#        [-412.33130259,  116.75213592],
#        [-412.38766855,  116.68926971],
#        ...,
#        [-421.72694773,   60.33019988],
#        [-421.74634928,   60.30694549],
#        [-421.75146097,   60.33593719]], shape=(35993, 2))}
#   mouth: (35993, 2), first three rows (i.e., frames): [[-348.6890449   201.10137908]
#  [-348.67471689  201.13073699]
#  [-348.69401926  201.07452361]]
#   L_eye: (35993, 2), first three rows (i.e., frames): [[-352.93083567  184.61950652]
#  [-352.91455454  184.64929168]
#  [-352.93664927  184.62347381]]
#   R_eye: (35993, 2), first three rows (i.e., frames): [[-364.55003733  193.06378143]
#  [-364.53732676  193.09271209]
#  [-364.55876536  193.06603973]]
#   spine: (35993, 2), first three rows (i.e., frames): [[-384.98889536  156.39727752]
#  [-384.9707374   156.43823211]
#  [-385.02096934  156.36590545]]
#   tail: (35993, 2), first three rows (i.e., frames): [[-412.34396738  116.70489471]
#  [-412.33130259  116.75213592]
#  [-412.38766855  116.68926971]]
#
#  track_data length is 35993
#   first 5 lengths for track track_0: [np.float64(167.69502898993676), np.float64(167.6717625672105), np.float64(167.73304035145986), np.float64(167.74631347926106), np.float64(167.7177012919601)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\ones\t3_1s.csv
# Calculating total distance for each track:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35993, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.917147  513.421692  767.694458     1.045790
# 1          1  track_0        0.922382  513.439453  767.707825     1.057172
# 2          2  track_0        0.924896  513.424316  767.729797     1.056266
# 3          3  track_0        0.924615  513.405701  767.684631     1.053562
# 4          4  track_0        0.924190  513.401489  767.696777     1.054546
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  513.186035  787.358398     1.011642  528.869263  ...    256.468066
# 1  513.182129  787.400024     1.014912  528.861816  ...    256.506814
# 2  513.177490  787.435974     1.010230  528.879883  ...    256.528825
# 3  513.164062  787.385071     1.009235  528.864136  ...    256.492330
# 4  513.155396  787.380493     1.009827  528.841370  ...    256.490352
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0    -1.652288    3.352047  336.052795   336.069513   -1.560822   -12.692203
# 1    -1.652305    3.360958  336.176635   336.193436   -1.560799   -12.684391
# 2    -1.652227    3.362118  336.184936   336.201748   -1.560796   -12.666691
# 3    -1.652301    3.327633  336.047302   336.063777   -1.560894   -12.701237
# 4    -1.652390    3.317562  335.992065   336.008443   -1.560923   -12.720280
#
#    spine_adj_y  spine_radius  spine_theta
# 0   299.363586    299.632523    -1.613168
# 1   299.414123    299.682684    -1.613135
# 2   299.491333    299.759076    -1.613065
# 3   299.423462    299.692727    -1.613190
# 4   299.409118    299.679205    -1.613255
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[ -36.32452769,  243.41204803],
#        [ -36.30676646,  243.42541473],
#        [ -36.32190317,  243.44738738],
#        ...,
#        [ -93.29324717, -195.08480866],
#        [ -93.29355234, -195.09625275],
#        [ -93.30530161, -195.09429963]], shape=(35993, 2)), 'L_eye': array([[ -36.56018442,  263.07598846],
#        [ -36.56409067,  263.11761443],
#        [ -36.56872935,  263.15356414],
#        ...,
#        [-105.74457163, -180.00619538],
#        [-105.73801035, -180.01043732],
#        [-105.75665659, -180.00231965]], shape=(35993, 2)), 'R_eye': array([[ -20.87695688,  255.61694305],
#        [ -20.88440317,  255.65521209],
#        [ -20.86633677,  255.67877166],
#        ...,
#        [ -90.07513804, -175.53646882],
#        [ -90.06738657, -175.54553254],
#        [ -90.07757944, -175.53390534]], shape=(35993, 2)), 'spine': array([[ -12.69220347,  299.36358611],
#        [ -12.68439097,  299.41412322],
#        [ -12.66669077,  299.4913327 ],
#        ...,
#        [-113.74060435, -135.76202424],
#        [-113.73279185, -135.75997956],
#        [-113.75207896, -135.7600406 ]], shape=(35993, 2)), 'tail': array([[   3.35204702,  336.0527951 ],
#        [   3.36095815,  336.17663543],
#        [   3.36211782,  336.18493621],
#        ...,
#        [-129.31543345,  -91.36151154],
#        [-129.31271738,  -91.34936555],
#        [-129.32153696,  -91.3499759 ]], shape=(35993, 2))}
#   mouth: (35993, 2), first three rows (i.e., frames): [[-36.32452769 243.41204803]
#  [-36.30676646 243.42541473]
#  [-36.32190317 243.44738738]]
#   L_eye: (35993, 2), first three rows (i.e., frames): [[-36.56018442 263.07598846]
#  [-36.56409067 263.11761443]
#  [-36.56872935 263.15356414]]
#   R_eye: (35993, 2), first three rows (i.e., frames): [[-20.87695688 255.61694305]
#  [-20.88440317 255.65521209]
#  [-20.86633677 255.67877166]]
#   spine: (35993, 2), first three rows (i.e., frames): [[-12.69220347 299.36358611]
#  [-12.68439097 299.41412322]
#  [-12.66669077 299.4913327 ]]
#   tail: (35993, 2), first three rows (i.e., frames): [[  3.35204702 336.0527951 ]
#  [  3.36095815 336.17663543]
#  [  3.36211782 336.18493621]]
#
#  track_data length is 35993
#   first 5 lengths for track track_0: [np.float64(167.33573944738055), np.float64(167.45632247441097), np.float64(167.52681854132965), np.float64(167.40518524138935), np.float64(167.3066913639897)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\ones\t4_1s.csv
# Calculating total distance for each track:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35992, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.822546  571.749512  964.206299     0.808567
# 1          1  track_0        0.821758  571.787903  964.201294     0.814460
# 2          2  track_0        0.822070  575.528259  964.306702     0.722057
# 3          3  track_0        0.823234  575.564209  964.299255     0.718172
# 4          4  track_0        0.817387  571.793579  964.165344     0.811942
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  599.656799  975.683228     0.962035  595.950073  ...    429.579382
# 1  599.716187  975.724121     0.972238  596.005249  ...    429.598305
# 2  599.681763  975.657104     0.910862  596.016113  ...    429.695532
# 3  599.754456  975.636780     0.917748  596.051819  ...    429.690519
# 4  599.806946  975.634583     0.984324  596.011536  ...    429.496190
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0    -1.463032  202.447384  411.926819   458.986543   -1.114000   116.922604
# 1    -1.462907  202.342648  411.881653   458.899818   -1.114162   116.949825
# 2    -1.462906  202.776180  411.866394   459.077451   -1.113300   120.996029
# 3    -1.462822  202.787167  411.870849   459.086301   -1.113282   121.045712
# 4    -1.462867  202.424313  411.841919   458.900172   -1.113964   116.944454
#
#    spine_adj_y  spine_radius  spine_theta
# 0   428.052429    443.733904    -1.304151
# 1   428.031250    443.720647    -1.304079
# 2   428.021606    444.794935    -1.295298
# 3   428.019531    444.806456    -1.295189
# 4   427.851257    443.545605    -1.303984
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[  22.00329214,  439.92388885],
#        [  22.04168325,  439.91888397],
#        [  25.7820397 ,  440.02429168],
#        ...,
#        [ 383.42229849, -173.16162141],
#        [ 383.41949087, -173.14996369],
#        [ 383.4125939 , -173.12316926]], shape=(35992, 2)), 'L_eye': array([[  49.91057974,  451.40081756],
#        [  49.96996694,  451.44171111],
#        [  49.93554312,  451.37469451],
#        ...,
#        [ 375.56194692, -201.27301057],
#        [ 375.5476647 , -201.22903474],
#        [ 375.5367394 , -201.19158967]], shape=(35992, 2)), 'R_eye': array([[  46.20385366,  427.08740203],
#        [  46.25902944,  427.10046356],
#        [  46.2698937 ,  427.19708221],
#        ...,
#        [ 355.32000356, -181.84661896],
#        [ 355.34655386, -181.79708894],
#        [ 355.3422814 , -181.75628693]], shape=(35992, 2)), 'spine': array([[ 116.92260366,  428.05242889],
#        [ 116.94982534,  428.03124969],
#        [ 120.99602896,  428.02160613],
#        ...,
#        [ 306.14904409, -259.11727936],
#        [ 306.14568716, -259.08258088],
#        [ 306.12554556, -259.02227814]], shape=(35992, 2)), 'tail': array([[ 202.44738394,  411.92681854],
#        [ 202.34264761,  411.88165252],
#        [ 202.77618032,  411.86639373],
#        ...,
#        [ 259.44598013, -305.60330231],
#        [ 259.45598989, -305.56440766],
#        [ 259.44616323, -305.52175935]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[ 22.00329214 439.92388885]
#  [ 22.04168325 439.91888397]
#  [ 25.7820397  440.02429168]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[ 49.91057974 451.40081756]
#  [ 49.96996694 451.44171111]
#  [ 49.93554312 451.37469451]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[ 46.20385366 427.08740203]
#  [ 46.25902944 427.10046356]
#  [ 46.2698937  427.19708221]]
#   spine: (35992, 2), first three rows (i.e., frames): [[116.92260366 428.05242889]
#  [116.94982534 428.03124969]
#  [120.99602896 428.02160613]]
#   tail: (35992, 2), first three rows (i.e., frames): [[202.44738394 411.92681854]
#  [202.34264761 411.88165252]
#  [202.77618032 411.86639373]]
#
#  track_data length is 35992
#   first 5 lengths for track track_0: [np.float64(286.2894566319212), np.float64(286.16918054990896), np.float64(283.7503052804839), np.float64(283.7259333187124), np.float64(286.24582228409224)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\ones\t5_1s.csv
# Calculating total distance for each track:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35992, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.840525  648.184814  944.263245     0.978166
# 1          1  track_0        0.837416  648.189514  944.271912     0.978206
# 2          2  track_0        0.837576  648.213257  944.281128     0.978316
# 3          3  track_0        0.838112  648.232178  944.291992     0.979816
# 4          4  track_0        0.838878  648.250977  944.293945     0.976953
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  628.780029  939.652100     0.977235  629.325989  ...    439.347875
# 1  628.766602  939.695312     0.975417  629.326538  ...    439.372585
# 2  628.782715  939.697571     0.975188  629.327271  ...    439.389885
# 3  628.792603  939.704285     0.975273  629.345703  ...    439.395685
# 4  628.795837  939.717529     0.974879  629.367554  ...    439.412669
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0    -1.388659  -21.440006  435.710144   436.237324   -1.619964    26.858395
# 1    -1.388668  -21.440739  435.725647   436.252845   -1.619964    26.855831
# 2    -1.388674  -21.400272  435.724426   436.249638   -1.619871    26.876339
# 3    -1.388634  -21.388004  435.734314   436.258913   -1.619842    26.887447
# 4    -1.388590  -21.399174  435.755005   436.280126   -1.619865    26.892757
#
#    spine_adj_y  spine_radius  spine_theta
# 0   431.862976    432.697358    -1.508684
# 1   431.872802    432.707006    -1.508692
# 2   431.876526    432.711995    -1.508645
# 3   431.888672    432.724808    -1.508621
# 4   431.919189    432.755597    -1.508613
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[ 98.43859487, 419.98083465],
#        [ 98.44329458, 419.98950164],
#        [ 98.46703726, 419.99871795],
#        ...,
#        [230.95629507, 352.50421111],
#        [230.95495229, 352.47106902],
#        [230.93859487, 352.46588104]], shape=(35992, 2)), 'L_eye': array([[ 79.03380972, 415.36968963],
#        [ 79.02038198, 415.41290252],
#        [ 79.03649526, 415.41516082],
#        ...,
#        [213.89641958, 356.26281707],
#        [213.90325552, 356.22479217],
#        [213.8825646 , 356.21978729]], shape=(35992, 2)), 'R_eye': array([[ 79.57976919, 432.08056609],
#        [ 79.58031851, 432.10559051],
#        [ 79.58105093, 432.12304656],
#        ...,
#        [222.31359487, 372.02679412],
#        [222.31249624, 372.00201385],
#        [222.31335073, 371.98211639]], shape=(35992, 2)), 'spine': array([[ 26.85839468, 431.86297576],
#        [ 26.8558312 , 431.87280242],
#        [ 26.87633901, 431.87652557],
#        ...,
#        [174.15771108, 395.8521115 ],
#        [174.16192251, 395.8607785 ],
#        [174.15020376, 395.85906951]], shape=(35992, 2)), 'tail': array([[-21.4400062 , 435.71014373],
#        [-21.44073862, 435.72564666],
#        [-21.40027231, 435.72442596],
#        ...,
#        [126.77355581, 419.85620086],
#        [126.76781851, 419.86675994],
#        [126.75219351, 419.87322967]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[ 98.43859487 419.98083465]
#  [ 98.44329458 419.98950164]
#  [ 98.46703726 419.99871795]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[ 79.03380972 415.36968963]
#  [ 79.02038198 415.41290252]
#  [ 79.03649526 415.41516082]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[ 79.57976919 432.08056609]
#  [ 79.58031851 432.10559051]
#  [ 79.58105093 432.12304656]]
#   spine: (35992, 2), first three rows (i.e., frames): [[ 26.85839468 431.86297576]
#  [ 26.8558312  431.87280242]
#  [ 26.87633901 431.87652557]]
#   tail: (35992, 2), first three rows (i.e., frames): [[-21.4400062  435.71014373]
#  [-21.44073862 435.72564666]
#  [-21.40027231 435.72442596]]
#
#  track_data length is 35992
#   first 5 lengths for track track_0: [np.float64(198.2452252621242), np.float64(198.24862890085095), np.float64(198.23771450130744), np.float64(198.24976972673417), np.float64(198.30119832172647)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\ones\t6_1s.csv
# Calculating total distance for each track:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35992, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.895635  336.746429  975.992615     0.993747
# 1          1  track_0        0.902330  344.702850  977.059204     0.995070
# 2          2  track_0        0.886208  355.820068  980.620239     0.997031
# 3          3  track_0        0.905312  365.056000  980.511719     0.993786
# 4          4  track_0        0.901868  372.727844  983.981567     0.955414
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  333.157501  953.140137     0.984527  317.273499  ...    497.910589
# 1  340.787659  956.910278     1.014678  328.102539  ...    496.697981
# 2  348.611542  960.566528     1.008681  336.245239  ...    496.680321
# 3  360.491943  960.665222     0.988706  345.517212  ...    495.740845
# 4  368.243347  964.125854     1.012939  356.200409  ...    494.680579
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0    -2.056574 -269.191288  332.299865   427.653072   -2.251657  -256.874699
# 1    -2.033349 -269.153995  339.972290   433.618532   -2.240452  -249.370121
# 2    -2.015130 -265.436314  348.189148   437.826586   -2.222144  -241.857365
# 3    -1.995408 -260.804356  355.587219   440.977530   -2.203619  -236.584110
# 4    -1.972790 -261.184727  363.558044   447.651553   -2.193773  -225.488468
#
#    spine_adj_y  spine_radius  spine_theta
# 0   388.218811    465.508814    -2.155335
# 1   392.573608    465.080095    -2.136710
# 2   400.491516    467.855147    -2.114080
# 3   407.790161    471.449739    -2.096501
# 4   411.686157    469.393802    -2.071887
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[-212.99979014,  451.71020477],
#        [-205.04336924,  452.77679412],
#        [-193.92615122,  456.33782928],
#        ...,
#        [-160.23767466,  396.28192107],
#        [-160.20294565,  396.34600799],
#        [-160.20276255,  396.38354461]], shape=(35992, 2)), 'L_eye': array([[-216.58871836,  428.85772674],
#        [-208.95856089,  432.62786834],
#        [-201.13467783,  436.28411834],
#        ...,
#        [-144.86554331,  412.30700652],
#        [-144.80932993,  412.3788449 ],
#        [-144.82794565,  412.39514129]], shape=(35992, 2)), 'R_eye': array([[-232.47272104,  440.30828826],
#        [-221.64368052,  444.50305145],
#        [-213.50098032,  448.4514157 ],
#        ...,
#        [-137.26556772,  396.17071502],
#        [-137.22363657,  396.22125213],
#        [-137.22272104,  396.27435272]], shape=(35992, 2)), 'spine': array([[-256.87469858,  388.21881072],
#        [-249.37012095,  392.57360809],
#        [-241.8573646 ,  400.4915158 ],
#        ...,
#        [ -92.64365   ,  423.97759979],
#        [ -92.61420054,  424.00646941],
#        [ -92.60998911,  424.04016082]], shape=(35992, 2)), 'tail': array([[-269.19128794,  332.29986541],
#        [-269.15399546,  339.97228973],
#        [-265.43631357,  348.18914764],
#        ...,
#        [ -40.61334604,  440.20294158],
#        [ -40.55804819,  440.25006072],
#        [ -40.53067393,  440.2838742 ]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[-212.99979014  451.71020477]
#  [-205.04336924  452.77679412]
#  [-193.92615122  456.33782928]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[-216.58871836  428.85772674]
#  [-208.95856089  432.62786834]
#  [-201.13467783  436.28411834]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[-232.47272104  440.30828826]
#  [-221.64368052  444.50305145]
#  [-213.50098032  448.4514157 ]]
#   spine: (35992, 2), first three rows (i.e., frames): [[-256.87469858  388.21881072]
#  [-249.37012095  392.57360809]
#  [-241.8573646   400.4915158 ]]
#   tail: (35992, 2), first three rows (i.e., frames): [[-269.19128794  332.29986541]
#  [-269.15399546  339.97228973]
#  [-265.43631357  348.18914764]]
#
#  track_data length is 35992
#   first 5 lengths for track track_0: [np.float64(217.7023023388172), np.float64(211.03878811231152), np.float64(209.71771713001948), np.float64(207.81897045425802), np.float64(203.6364758639681)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\ones\t7_1s.csv
# Calculating total distance for each track:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35993, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.960382  227.108246  333.396118     0.956130
# 1          1  track_0        0.960673  227.018982  333.471741     0.950727
# 2          2  track_0        0.953323  226.708008  333.676208     0.953431
# 3          3  track_0        0.952059  226.518219  333.695862     0.946316
# 4          4  track_0        0.953459  223.449432  333.699341     0.958088
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  246.385651  317.380890     0.971353  226.682953  ...    387.728308
# 1  243.312531  317.545013     0.987039  226.548294  ...    387.784181
# 2  243.083649  317.801025     1.005195  226.393372  ...    387.835442
# 3  242.927338  317.885559     1.001297  223.392868  ...    390.347588
# 4  242.738708  317.964844     0.997353  223.264297  ...    390.456460
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0     2.555703 -275.065708 -306.557602   411.872198    2.302102  -294.945377
# 1     2.556114 -275.126011 -306.264557   411.694427    2.302687  -294.950382
# 2     2.556638 -275.168339 -305.886719   411.441733    2.303377  -294.960453
# 3     2.560855 -275.086369 -305.818848   411.336453    2.303339  -294.948002
# 4     2.561031 -275.057468 -302.878113   409.135384    2.308094  -294.943378
#
#    spine_adj_y  spine_radius  spine_theta
# 0  -258.814331    392.399839     2.421349
# 1  -258.697571    392.326600     2.421581
# 2  -258.515595    392.214204     2.421947
# 3  -258.483094    392.183418     2.421988
# 4  -258.474305    392.174148     2.421997
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[-322.63797373, -190.88629182],
#        [-322.72723765, -190.81066926],
#        [-323.03821177, -190.60620148],
#        ...,
#        [-141.79230112, -367.69860871],
#        [-141.86853403, -367.70121796],
#        [-141.99264902, -367.73010285]], shape=(35993, 2)), 'L_eye': array([[-303.36056895, -206.90152009],
#        [-306.43368906, -206.73739655],
#        [-306.6625709 , -206.48138459],
#        ...,
#        [-162.3818397 , -371.69168122],
#        [-162.50220103, -371.68377717],
#        [-162.63837046, -371.66601594]], shape=(35993, 2)), 'R_eye': array([[-323.0632667 , -214.39068635],
#        [-323.19792551, -214.28875764],
#        [-323.352848  , -214.14776643],
#        ...,
#        [-157.80115122, -352.13900788],
#        [-157.88827891, -352.11810334],
#        [-158.04083628, -352.11297639]], shape=(35993, 2)), 'spine': array([[-294.94537729, -258.81433137],
#        [-294.95038218, -258.69757111],
#        [-294.96045298, -258.51559479],
#        ...,
#        [-213.81824106, -343.78601105],
#        [-213.83002085, -343.79737885],
#        [-213.87994761, -343.75872834]], shape=(35993, 2)), 'tail': array([[-275.06570811, -306.55760224],
#        [-275.12601084, -306.2645572 ],
#        [-275.16833872, -305.88671906],
#        ...,
#        [-257.84988779, -319.27717622],
#        [-257.94672007, -319.22100861],
#        [-258.03250498, -319.21302827]], shape=(35993, 2))}
#   mouth: (35993, 2), first three rows (i.e., frames): [[-322.63797373 -190.88629182]
#  [-322.72723765 -190.81066926]
#  [-323.03821177 -190.60620148]]
#   L_eye: (35993, 2), first three rows (i.e., frames): [[-303.36056895 -206.90152009]
#  [-306.43368906 -206.73739655]
#  [-306.6625709  -206.48138459]]
#   R_eye: (35993, 2), first three rows (i.e., frames): [[-323.0632667  -214.39068635]
#  [-323.19792551 -214.28875764]
#  [-323.352848   -214.14776643]]
#   spine: (35993, 2), first three rows (i.e., frames): [[-294.94537729 -258.81433137]
#  [-294.95038218 -258.69757111]
#  [-294.96045298 -258.51559479]]
#   tail: (35993, 2), first three rows (i.e., frames): [[-275.06570811 -306.55760224]
#  [-275.12601084 -306.2645572 ]
#  [-275.16833872 -305.88671906]]
#
#  track_data length is 35993
#   first 5 lengths for track track_0: [np.float64(205.45195188542272), np.float64(203.6455891576249), np.float64(203.6993763528038), np.float64(205.64353708053804), np.float64(205.04966838952933)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\ones\t8_1s.csv
# Calculating total distance for each track:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35992, 38)
#    frame_idx    track  instance.score     mouth.x    mouth.y  mouth.score  \
# 0          0  track_0        0.862108  532.168213  97.480316     1.007488
# 1          1  track_0        0.843350  532.088501  94.036438     1.004651
# 2          2  track_0        0.873974  531.537598  93.967339     0.990262
# 3          3  track_0        0.886982  531.100403  93.844391     0.985002
# 4          4  track_0        0.891424  527.864563  97.209946     0.995086
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  547.654053  125.830612     1.001971  564.116943  ...    419.069288
# 1  547.556519  125.703148     0.970640  564.085999  ...    419.242321
# 2  544.189514  125.587921     0.985620  563.600647  ...    419.318540
# 3  543.737793  125.406906     0.995877  563.132202  ...    419.428908
# 4  543.474365  125.515190     1.001814  562.837402  ...    419.339953
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0     1.536498  134.428524 -314.723969   342.231215    1.167122    66.397823
# 1     1.536586  130.679256 -315.019989   341.049354    1.177573    62.616085
# 2     1.537750  130.174496 -315.149857   340.976292    1.179086    62.315182
# 3     1.538876  129.713863 -315.394074   341.026551    1.180608    62.053707
# 4     1.539573  129.552303 -315.366242   340.939387    1.181015    65.010128
#
#    spine_adj_y  spine_radius  spine_theta
# 0  -358.551789    364.647852     1.387687
# 1  -359.006775    364.426452     1.398119
# 2  -359.032990    364.400699     1.398944
# 3  -359.155518    364.476815     1.399709
# 4  -362.261139    368.048162     1.393230
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[ -17.57800669, -426.80209382],
#        [ -17.6577186 , -430.24597199],
#        [ -18.20862192, -430.31507142],
#        ...,
#        [-364.34828562, -216.60168488],
#        [-364.07690806, -216.85418732],
#        [-367.10200876, -220.21023591]], shape=(35992, 2)), 'L_eye': array([[  -2.09216685, -398.4517978 ],
#        [  -2.18970103, -398.57926209],
#        [  -5.55670542, -398.69448884],
#        ...,
#        [-336.51065439, -228.39056428],
#        [-336.25300974, -228.637482  ],
#        [-336.18785471, -228.95184357]], shape=(35992, 2)), 'R_eye': array([[  14.37072378, -418.82281525],
#        [  14.33977896, -418.99700959],
#        [  13.85442739, -419.08959992],
#        ...,
#        [-352.78876108, -248.36254914],
#        [-352.55255503, -248.64990266],
#        [-352.41751475, -248.98312409]], shape=(35992, 2)), 'spine': array([[  66.39782339, -358.55178864],
#        [  62.61608511, -359.00677521],
#        [  62.31518179, -359.03298981],
#        ...,
#        [-288.40231699, -297.82034333],
#        [-288.27124399, -297.92761262],
#        [-284.22601694, -301.85261567]], shape=(35992, 2)), 'tail': array([[ 134.42852407, -314.72396882],
#        [ 130.67925649, -315.01998933],
#        [ 130.17449575, -315.14985688],
#        ...,
#        [-227.77496714, -356.54498322],
#        [-227.60260386, -356.81842072],
#        [-223.84588999, -360.04154999]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[ -17.57800669 -426.80209382]
#  [ -17.6577186  -430.24597199]
#  [ -18.20862192 -430.31507142]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[  -2.09216685 -398.4517978 ]
#  [  -2.18970103 -398.57926209]
#  [  -5.55670542 -398.69448884]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[  14.37072378 -418.82281525]
#  [  14.33977896 -418.99700959]
#  [  13.85442739 -419.08959992]]
#   spine: (35992, 2), first three rows (i.e., frames): [[  66.39782339 -358.55178864]
#  [  62.61608511 -359.00677521]
#  [  62.31518179 -359.03298981]]
#   tail: (35992, 2), first three rows (i.e., frames): [[ 134.42852407 -314.72396882]
#  [ 130.67925649 -315.01998933]
#  [ 130.17449575 -315.14985688]]
#
#  track_data length is 35992
#   first 5 lengths for track track_0: [np.float64(305.04546785245594), np.float64(303.13499469184546), np.float64(304.6221363274068), np.float64(304.6254699570103), np.float64(305.0607663232787)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\twos\t1_2s.csv
# Calculating total distance for each track:   0%|          | 0/2 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35993, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.912975  923.857483  680.255493     1.020015
# 1          1  track_0        0.913251  923.871155  680.229736     1.019310
# 2          2  track_0        0.912441  923.852234  680.227661     1.020014
# 3          3  track_0        0.911385  923.831055  680.242920     1.019875
# 4          4  track_0        0.910509  923.841248  680.253479     1.019514
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  943.670227  660.619385     0.973273  923.700073  ...    395.411002
# 1  943.675598  660.613220     0.971787  923.703064  ...    395.411827
# 2  943.680176  660.582886     0.974263  923.692810  ...    395.406156
# 3  943.653076  660.613220     0.973601  923.680420  ...    395.403464
# 4  943.638794  660.654358     0.975098  923.668335  ...    395.398285
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0    -0.330948  422.908810   19.864319   423.375073   -0.046936   406.269527
# 1    -0.330931  422.904232   19.796081   423.367304   -0.046776   406.269650
# 2    -0.330969  422.892208   19.868469   423.358685   -0.046948   406.259335
# 3    -0.331046  422.877804   19.914245   423.346447   -0.047057   406.250973
# 4    -0.331102  422.853024   19.934814   423.322662   -0.047109   406.231075
#
#    spine_adj_y  spine_radius  spine_theta
# 0    76.344665    413.380499    -0.185750
# 1    76.328125    413.377564    -0.185711
# 2    76.350341    413.371530    -0.185768
# 3    76.380737    413.368927    -0.185844
# 4    76.403137    413.353512    -0.185906
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[ 374.11126333,  155.97308318],
#        [ 374.12493521,  155.94732635],
#        [ 374.10601431,  155.94525115],
#        ...,
#        [-417.24864573,  -87.40850861],
#        [-417.25148386,  -87.43273957],
#        [-417.25061411,  -87.45111115]], shape=(35993, 2)), 'L_eye': array([[ 393.92400747,  136.33697479],
#        [ 393.92937856,  136.33081023],
#        [ 393.9339562 ,  136.30047576],
#        ...,
#        [-396.84901804,  -99.29516633],
#        [-396.84975046,  -99.32159455],
#        [-396.85052866,  -99.33578522]], shape=(35993, 2)), 'R_eye': array([[ 373.95385366,  128.484924  ],
#        [ 373.95684438,  128.47875945],
#        [ 373.94659048,  128.49114959],
#        ...,
#        [-409.42712778, -111.56124909],
#        [-409.43199534, -111.56652863],
#        [-409.42901987, -111.5798343 ]], shape=(35993, 2)), 'spine': array([[ 406.26952749,   76.34466522],
#        [ 406.26964956,   76.32812469],
#        [ 406.25933462,   76.35034148],
#        ...,
#        [-365.1217689 , -151.48239167],
#        [-365.11926646, -151.50567658],
#        [-365.12295908, -151.51727326]], shape=(35993, 2)), 'tail': array([[ 422.90880972,   19.86431854],
#        [ 422.90423208,   19.79608123],
#        [ 422.89220815,   19.86846893],
#        ...,
#        [-332.57844919, -199.39059479],
#        [-332.5549354 , -199.40499909],
#        [-332.54144663, -199.37030061]], shape=(35993, 2))}
#   mouth: (35993, 2), first three rows (i.e., frames): [[374.11126333 155.97308318]
#  [374.12493521 155.94732635]
#  [374.10601431 155.94525115]]
#   L_eye: (35993, 2), first three rows (i.e., frames): [[393.92400747 136.33697479]
#  [393.92937856 136.33081023]
#  [393.9339562  136.30047576]]
#   R_eye: (35993, 2), first three rows (i.e., frames): [[373.95385366 128.484924  ]
#  [373.95684438 128.47875945]
#  [373.94659048 128.49114959]]
#   spine: (35993, 2), first three rows (i.e., frames): [[406.26952749  76.34466522]
#  [406.26964956  76.32812469]
#  [406.25933462  76.35034148]]
#   tail: (35993, 2), first three rows (i.e., frames): [[422.90880972  19.86431854]
#  [422.90423208  19.79608123]
#  [422.89220815  19.86846893]]
#
#  track_data length is 35993
#   first 5 lengths for track track_0: [np.float64(236.85574582948627), np.float64(236.88120961589905), np.float64(236.79180435390995), np.float64(236.7515736151951), np.float64(236.71491631463192)]
# Processing track_id: track_1, track_data shape: (35993, 38)
#        frame_idx    track  instance.score     mouth.x     mouth.y  \
# 35993          0  track_1        0.873243  340.667480  148.133026
# 35994          1  track_1        0.873670  340.666321  148.124710
# 35995          2  track_1        0.867245  340.633362  148.074081
# 35996          3  track_1        0.868346  340.655945  148.089920
# 35997          4  track_1        0.866151  340.684479  148.083069
#
#        mouth.score     L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  \
# 35993     0.993103  320.959442  152.082733     0.967520  332.433167  ...
# 35994     0.992613  320.955627  152.072021     0.969069  332.428070  ...
# 35995     0.988295  320.955231  152.027557     0.971226  332.464142  ...
# 35996     0.987594  320.976501  152.025696     0.971593  332.478546  ...
# 35997     0.991544  321.000854  152.023636     0.969996  332.488068  ...
#
#        R_eye_radius  R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  \
# 35993    420.560968     2.113814 -296.716373 -304.081391   424.860093
# 35994    420.562582     2.113826 -296.709385 -304.086914   424.859166
# 35995    420.601703     2.113669 -296.691135 -304.179352   424.912589
# 35996    420.588291     2.113649 -296.683796 -304.167923   424.899283
# 35997    420.586299     2.113625 -296.693211 -304.157791   424.898604
#
#        tail_theta  spine_adj_x  spine_adj_y  spine_radius  spine_theta
# 35993    2.343936  -261.050419  -332.401154    422.655709     2.236539
# 35994    2.343916  -261.052280  -332.411866    422.665283     2.236527
# 35995    2.343733  -261.074650  -332.454560    422.712677     2.236506
# 35996    2.343739  -261.065739  -332.440430    422.696060     2.236510
# 35997    2.343772  -261.060856  -332.419525    422.676604     2.236531
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[-209.07873911, -376.14938386],
#        [-209.07989878, -376.1576999 ],
#        [-209.11285776, -376.20832856],
#        ...,
#        [-358.48196787, -208.03665192],
#        [-358.45465464, -208.0565799 ],
#        [-358.44348521, -208.04986603]], shape=(35993, 2)), 'L_eye': array([[-228.78677744, -372.19967683],
#        [-228.79059214, -372.2103885 ],
#        [-228.79098887, -372.25485261],
#        ...,
#        [-342.01730723, -215.36532624],
#        [-341.99254221, -215.39453156],
#        [-341.97467417, -215.39514191]], shape=(35993, 2)), 'R_eye': array([[-217.31305308, -360.06466706],
#        [-217.31814951, -360.06347687],
#        [-217.28207773, -360.13093598],
#        ...,
#        [-353.41272349, -227.29492219],
#        [-353.38992686, -227.32031281],
#        [-353.39036936, -227.33325227]], shape=(35993, 2)), 'spine': array([[-261.0504188 , -332.40115388],
#        [-261.05228037, -332.41186555],
#        [-261.07464976, -332.45455964],
#        ...,
#        [-309.8951301 , -251.91137727],
#        [-309.85779185, -251.94937165],
#        [-309.84613413, -251.95758088]], shape=(35993, 2)), 'tail': array([[-296.71637339, -304.08139069],
#        [-296.70938486, -304.08691437],
#        [-296.69113535, -304.17935212],
#        ...,
#        [-273.34192271, -287.8555301 ],
#        [-270.34613413, -287.93005402],
#        [-270.32898325, -287.84751923]], shape=(35993, 2))}
#   mouth: (35993, 2), first three rows (i.e., frames): [[-209.07873911 -376.14938386]
#  [-209.07989878 -376.1576999 ]
#  [-209.11285776 -376.20832856]]
#   L_eye: (35993, 2), first three rows (i.e., frames): [[-228.78677744 -372.19967683]
#  [-228.79059214 -372.2103885 ]
#  [-228.79098887 -372.25485261]]
#   R_eye: (35993, 2), first three rows (i.e., frames): [[-217.31305308 -360.06466706]
#  [-217.31814951 -360.06347687]
#  [-217.28207773 -360.13093598]]
#   spine: (35993, 2), first three rows (i.e., frames): [[-261.0504188  -332.40115388]
#  [-261.05228037 -332.41186555]
#  [-261.07464976 -332.45455964]]
#   tail: (35993, 2), first three rows (i.e., frames): [[-296.71637339 -304.08139069]
#  [-296.70938486 -304.08691437]
#  [-296.69113535 -304.17935212]]
#
#  track_data length is 35993
#   first 5 lengths for track track_1: [np.float64(186.69682301122597), np.float64(186.69518249355684), np.float64(186.63321483729806), np.float64(186.65505146227719), np.float64(186.72330468390754)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Processing file: allcsvs\twos\t2_2s.csv
# Calculating total distance for each track:   0%|          | 0/2 [00:00<?, ?it/s]
# Processing track_id: track_0, track_data shape: (35992, 38)
#    frame_idx    track  instance.score     mouth.x     mouth.y  mouth.score  \
# 0          0  track_0        0.831865  931.842529  696.309570     1.067081
# 1          1  track_0        0.833493  931.806519  696.310547     1.063081
# 2          2  track_0        0.833116  931.725159  696.279358     1.048276
# 3          3  track_0        0.835649  931.726074  696.251282     1.049586
# 4          4  track_0        0.837027  931.702759  696.318970     1.048207
#
#       L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  R_eye_radius  \
# 0  908.592773  712.510437     0.879188  931.987366  ...    431.538916
# 1  908.596558  712.490479     0.878320  931.971191  ...    431.518470
# 2  908.562988  712.457703     0.877751  932.002502  ...    431.499730
# 3  908.565491  712.428589     0.877896  931.977844  ...    431.470241
# 4  908.535767  712.462219     0.876753  931.960327  ...    431.484600
#
#    R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  tail_theta  spine_adj_x  \
# 0    -0.482661  306.655575  328.245544   449.202381   -0.819390   338.307064
# 1    -0.482652  306.645626  328.272827   449.215526   -0.819448   338.313595
# 2    -0.482412  306.784603  328.094787   449.180345   -0.818951   338.327938
# 3    -0.482405  306.785152  328.090881   449.177867   -0.818944   338.343136
# 4    -0.482556  306.748531  328.209167   449.239267   -0.819184   338.320614
#
#    spine_adj_y  spine_radius  spine_theta
# 0   264.073913    429.169781    -0.662783
# 1   264.094055    429.187323    -0.662811
# 2   264.024658    429.155932    -0.662663
# 3   264.007324    429.157249    -0.662609
# 4   264.103210    429.198490    -0.662818
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[382.09630972, 172.02716033],
#        [382.06029897, 172.02813689],
#        [381.97893911, 171.99694793],
#        ...,
#        [139.28368765, 424.0606076 ],
#        [139.28167349, 424.02844207],
#        [139.30346304, 424.03497283]], shape=(35992, 2)), 'L_eye': array([[358.84655386, 188.22802703],
#        [358.85033804, 188.20806854],
#        [358.8167687 , 188.17529266],
#        ...,
#        [170.53753286, 420.63134734],
#        [170.54327017, 420.57427947],
#        [170.55334097, 420.571716  ]], shape=(35992, 2)), 'R_eye': array([[382.24114614, 200.29363982],
#        [382.22497183, 200.28045623],
#        [382.25628286, 200.18029754],
#        ...,
#        [158.70129019, 400.47100799],
#        [158.72704702, 400.43102996],
#        [158.72289663, 400.42944305]], shape=(35992, 2)), 'spine': array([[338.30706411, 264.07391326],
#        [338.31359487, 264.09405486],
#        [338.32793813, 264.02465789],
#        ...,
#        [240.91332632, 386.48480193],
#        [240.99065786, 386.4479367 ],
#        [240.9797936 , 386.44683807]], shape=(35992, 2)), 'tail': array([[306.65557485, 328.24554412],
#        [306.64562612, 328.27282684],
#        [306.78460317, 328.09478729],
#        ...,
#        [294.80675894, 343.83465545],
#        [294.82415396, 343.8140866 ],
#        [294.8402062 , 343.80108611]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[382.09630972 172.02716033]
#  [382.06029897 172.02813689]
#  [381.97893911 171.99694793]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[358.84655386 188.22802703]
#  [358.85033804 188.20806854]
#  [358.8167687  188.17529266]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[382.24114614 200.29363982]
#  [382.22497183 200.28045623]
#  [382.25628286 200.18029754]]
#   spine: (35992, 2), first three rows (i.e., frames): [[338.30706411 264.07391326]
#  [338.31359487 264.09405486]
#  [338.32793813 264.02465789]]
#   tail: (35992, 2), first three rows (i.e., frames): [[306.65557485 328.24554412]
#  [306.64562612 328.27282684]
#  [306.78460317 328.09478729]]
#
#  track_data length is 35992
#   first 5 lengths for track track_0: [np.float64(284.18269178729855), np.float64(284.19027982709946), np.float64(283.9166487689393), np.float64(283.9294011438203), np.float64(284.02527246151385)]
# Processing track_id: track_1, track_data shape: (35992, 38)
#        frame_idx    track  instance.score     mouth.x     mouth.y  \
# 35992          0  track_1        0.908640  559.752136  964.541077
# 35993          1  track_1        0.910858  559.764709  964.548096
# 35994          2  track_1        0.907232  559.785706  964.536316
# 35995          3  track_1        0.910566  559.814331  964.545715
# 35996          4  track_1        0.911428  559.829041  964.568909
#
#        mouth.score     L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  \
# 35992     0.994130  579.628540  975.642517     0.958722  579.479004  ...
# 35993     0.991021  579.657959  975.639160     0.959131  579.504395  ...
# 35994     0.994516  579.605957  975.611633     0.949629  576.585815  ...
# 35995     0.995917  579.640747  975.615417     0.949895  576.614502  ...
# 35996     0.996211  579.660034  975.632263     0.952057  576.623047  ...
#
#        R_eye_radius  R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  \
# 35992    436.185757    -1.502578  122.570980  439.485351   456.257624
# 35993    436.176589    -1.502518  122.597652  439.498718   456.277665
# 35994    435.966967    -1.509194  122.564449  439.479919   456.250637
# ...
#        [ 194.93505483,  387.56036346],
#        [ 195.07793813,  390.54174773],
#        [ 195.03728872,  390.57391326]], shape=(35992, 2)), 'L_eye': array([[-217.69519419, -366.42483552],
#        [-202.20599741, -372.45861848],
#        [-187.18500132, -385.19944794],
#        ...,
#        [ 226.91070181,  383.50274627],
#        [ 226.91900259,  383.51769988],
#        [ 226.86602407,  383.5227658 ]], shape=(35992, 2)), 'R_eye': array([[-205.14059824, -346.17500336],
#        [-186.78577036, -352.06854279],
#        [-171.92859263, -361.86029084],
#        ...,
#        [ 210.82079702,  363.29363982],
#        [ 210.85192495,  363.26678436],
#        [ 210.79876333,  363.32318084]], shape=(35992, 2)), 'spine': array([[-273.10095591, -313.97802766],
#        [-254.2955665 , -323.99075349],
#        [-236.38098521, -333.689133  ],
#        ...,
#        [ 286.54687124,  337.28991668],
#        [ 286.57818228,  337.29229705],
#        [ 286.55132681,  337.29022186]], shape=(35992, 2)), 'tail': array([[-321.9901771 , -249.93283112],
#        [-313.92584604, -268.10736115],
#        [-303.93933481, -284.99783356],
#        ...,
#        [ 342.63238149,  274.99493377],
#        [ 342.66662222,  274.86737029],
#        [ 342.53686147,  274.86718719]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[-189.08075327 -373.69401581]
#  [-170.25604624 -379.41842683]
#  [-155.7827186  -389.25051911]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[-217.69519419 -366.42483552]
#  [-202.20599741 -372.45861848]
#  [-187.18500132 -385.19944794]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[-205.14059824 -346.17500336]
#  [-186.78577036 -352.06854279]
#  [-171.92859263 -361.86029084]]
#   spine: (35992, 2), first three rows (i.e., frames): [[-273.10095591 -313.97802766]
#  [-254.2955665  -323.99075349]
#  [-236.38098521 -333.689133  ]]
#   tail: (35992, 2), first three rows (i.e., frames): [[-321.9901771  -249.93283112]
#  [-313.92584604 -268.10736115]
#  [-303.93933481 -284.99783356]]
#
#  track_data length is 35992
#   first 5 lengths for track track_0: [np.float64(293.4517740544141), np.float64(290.64648504885804), np.float64(288.3028435970728), np.float64(296.41053573373085), np.float64(294.1210278104708)]
# Processing track_id: track_1, track_data shape: (35992, 38)
#        frame_idx    track  instance.score     mouth.x     mouth.y  \
# 35992          0  track_1        0.963855  316.506622  657.173096
# 35993          1  track_1        0.963751  316.292023  654.282166
# 35994          2  track_1        0.962430  315.918884  657.215454
# 35995          3  track_1        0.959775  315.514771  657.244507
# 35996          4  track_1        0.960744  315.399933  654.367432
#
#        mouth.score     L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  \
# 35992     0.952118  332.575745  661.704102     0.987892  331.872467  ...
# 35993     0.950088  332.319824  661.699280     0.989219  331.584015  ...
# 35994     0.960225  331.919922  661.707947     0.989491  328.406738  ...
# 35995     0.958515  331.552917  661.766357     0.988044  327.990662  ...
# 35996     0.960146  328.430359  661.831421     0.990350  327.779175  ...
#
#        R_eye_radius  R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  \
# 35992    249.451788    -2.632958 -120.790623  113.255554   165.581385
# 35993    249.687227    -2.633640 -120.946964  113.327697   165.744789
# 35994    252.445121    -2.639927 -120.997745  113.413574   165.840565
# 35995    252.825779    -2.640604 -121.566898  113.582092   166.371279
# 35996    253.094036    -2.640408 -121.852116  113.696045   166.657519
#
#        tail_theta  spine_adj_x  spine_adj_y  spine_radius  spine_theta
# 35992   -2.388378  -169.309635   125.581665    210.799685    -2.503407
# 35993   -2.388706  -169.418400   125.600769    210.898429    -2.503641
# 35994   -2.388537  -169.521488   125.565857    210.960469    -2.504065
# 35995   -2.390138  -169.794132   125.586792    211.192068    -2.504754
# 35996   -2.390807  -173.589664   125.618713    214.274200    -2.515168
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[-233.23959727,  132.89068572],
#        [-233.45419687,  129.99975555],
#        [-233.8273353 ,  132.93304412],
#        ...,
#        [ 174.01934438,  171.1699826 ],
#        [ 163.57067495,  178.02123992],
#        [ 154.30822378,  181.33251922]], shape=(35992, 2)), 'L_eye': array([[-217.17047495,  137.42169158],
#        [-217.42639536,  137.41686981],
#        [-217.82629771,  137.4255368 ],
#        ...,
#        [ 185.94646841,  182.47528045],
#        [ 176.37218862,  185.91497772],
#        [ 167.23131948,  188.8899533 ]], shape=(35992, 2)), 'R_eye': array([[-217.87375254,  121.47930877],
#        [-218.16220469,  121.44531219],
#        [-221.3394813 ,  121.3975827 ],
#        ...,
#        [ 189.88421255,  166.97100799],
#        [ 176.37176138,  170.10656707],
#        [ 166.91576772,  173.09753387]], shape=(35992, 2)), 'spine': array([[-169.30963511,  125.58166473],
#        [-169.41839976,  125.60076873],
#        [-169.52148813,  125.56585662],
#        ...,
#        [ 226.22814565,  190.76934783],
#        [ 220.27495962,  181.5239865 ],
#        [ 211.26171499,  180.97888152]], shape=(35992, 2)), 'tail': array([[-120.79062266,  113.25555389],
#        [-120.94696421,  113.32769744],
#        [-120.99774546,  113.41357391],
#        ...,
#        [ 233.56750112,  238.4869992 ],
#        [ 240.48980337,  225.53778045],
#        [ 246.80498892,  213.34344451]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[-233.23959727  132.89068572]
#  [-233.45419687  129.99975555]
#  [-233.8273353   132.93304412]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[-217.17047495  137.42169158]
#  [-217.42639536  137.41686981]
#  [-217.82629771  137.4255368 ]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[-217.87375254  121.47930877]
#  [-218.16220469  121.44531219]
#  [-221.3394813   121.3975827 ]]
#   spine: (35992, 2), first three rows (i.e., frames): [[-169.30963511  125.58166473]
#  [-169.41839976  125.60076873]
#  [-169.52148813  125.56585662]]
#   tail: (35992, 2), first three rows (i.e., frames): [[-120.79062266  113.25555389]
#  [-120.94696421  113.32769744]
#  [-120.99774546  113.41357391]]
#
#  track_data length is 35992
#   first 5 lengths for track track_1: [np.float64(183.9363554356117), np.float64(183.54533832358842), np.float64(185.36720150815742), np.float64(185.31869031469097), np.float64(180.85532100596618)]
# Processing track_id: track_2, track_data shape: (35992, 38)
#        frame_idx    track  instance.score     mouth.x     mouth.y  \
# 71984          0  track_2        0.961939  421.594604  282.040039
# 71985          1  track_2        0.957748  421.594208  282.127197
# 71986          2  track_2        0.945121  421.593445  282.189636
# 71987          3  track_2        0.956995  416.906372  283.407501
# 71988          4  track_2        0.965367  411.934784  288.042664
#
#        mouth.score     L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  \
# 71984     0.922281  448.699585  273.686310     0.977103  433.020599  ...
# 71985     0.925062  448.731323  273.792145     0.979043  433.060242  ...
# 71986     0.930184  448.784058  273.919434     0.965007  433.173920  ...
# 71987     0.903768  444.055756  275.423553     0.942336  428.766449  ...
# 71988     0.920203  436.182861  280.227661     0.921871  423.961945  ...
#
#        R_eye_radius  R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  \
# 71984    290.843388     1.983770  -16.865787 -342.233643   342.648977
# 71985    290.703651     1.983832  -16.879032 -342.048981   342.465191
# 71986    290.647250     1.983490  -16.940189 -341.918518   342.337908
# 71987    288.446146     2.003601  -21.573124 -337.474243   338.163074
# 71988    288.885209     2.021293  -26.013676 -332.165284   333.182363
#
#        tail_theta  spine_adj_x  spine_adj_y  spine_radius  spine_theta
# 71984    1.620038   -64.834385  -298.513428    305.473017     1.784666
# 71985    1.620103   -64.873142  -298.424622    305.394465     1.784851
# 71986    1.620300   -68.729496  -294.607972    302.518761     1.799988
# 71987    1.634635   -69.489963  -289.438813    297.663705     1.806422
# 71988    1.648952   -74.090397  -284.541718    294.029550     1.825525
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[-128.15161509, -242.24237092],
#        [-128.15201182, -242.15521271],
#        [-128.15277476, -242.09277375],
#        ...,
#        [-273.34265513, -241.79196198],
#        [-274.91263193, -236.86480744],
#        [-279.24057383, -232.12487824]], shape=(35992, 2)), 'L_eye': array([[-101.04663462, -250.59610017],
#        [-101.01489634, -250.4902652 ],
#        [-100.96216196, -250.36297639],
#        ...,
#        [-253.36825937, -257.4617923 ],
#        [-254.93957896, -252.50762971],
#        [-259.21442026, -247.88012727]], shape=(35992, 2)), 'R_eye': array([[-116.72562021, -266.39257844],
#        [-116.68597788, -266.25738557],
#        [-116.5722999 , -266.24560578],
#        ...,
#        [-270.01349253, -265.91735871],
#        [-274.34997935, -261.01452668],
#        [-278.68378062, -256.34301789]], shape=(35992, 2)), 'spine': array([[ -64.83438486, -298.51342805],
#        [ -64.87314219, -298.42462189],
#        [ -68.72949595, -294.6079715 ],
#        ...,
#        [-230.11212534, -313.61917145],
#        [-234.76449961, -308.77816804],
#        [-239.3462562 , -304.09310944]], shape=(35992, 2)), 'tail': array([[ -16.86578745, -342.23364289],
#        [ -16.87903208, -342.04898102],
#        [ -16.94018931, -341.91851838],
#        ...,
#        [-182.25641245, -357.58862336],
#        [-190.53552622, -356.79983552],
#        [-198.7094459 , -355.59056123]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[-128.15161509 -242.24237092]
#  [-128.15201182 -242.15521271]
#  [-128.15277476 -242.09277375]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[-101.04663462 -250.59610017]
#  [-101.01489634 -250.4902652 ]
#  [-100.96216196 -250.36297639]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[-116.72562021 -266.39257844]
#  [-116.68597788 -266.25738557]
#  [-116.5722999  -266.24560578]]
#   spine: (35992, 2), first three rows (i.e., frames): [[ -64.83438486 -298.51342805]
#  [ -64.87314219 -298.42462189]
#  [ -68.72949595 -294.6079715 ]]
#   tail: (35992, 2), first three rows (i.e., frames): [[ -16.86578745 -342.23364289]
#  [ -16.87903208 -342.04898102]
#  [ -16.94018931 -341.91851838]]
#
#  track_data length is 35992
#   first 5 lengths for track track_2: [np.float64(241.0730785412426), np.float64(240.95533490865472), np.float64(235.71063577824884), np.float64(233.0387322383338), np.float64(233.57615610268903)]
# Processing track_id: track_3, track_data shape: (35992, 38)
#         frame_idx    track  instance.score     mouth.x     mouth.y  \
# 107976          0  track_3        0.975380  218.534592  485.451141
# 107977          1  track_3        0.971809  218.253540  485.186462
# 107978          2  track_3        0.964000  218.038864  484.861633
# 107979          3  track_3        0.963327  217.898621  484.919495
# 107980          4  track_3        0.969738  214.707947  484.698059
#
#         mouth.score     L_eye.x     L_eye.y  L_eye.score     R_eye.x  ...  \
# 107976     0.949416  235.113586  481.476318     0.982128  226.295227  ...
# 107977     0.952640  234.881226  481.221436     1.003994  226.067276  ...
# 107978     0.952631  234.717590  480.934082     1.014031  225.966324  ...
# 107979     0.962891  234.414230  480.910126     1.002761  222.816620  ...
# 107980     0.940292  234.123581  480.710510     0.994130  222.582703  ...
#
#         R_eye_radius  R_eye_theta  tail_adj_x  tail_adj_y  tail_radius  \
# 107976    328.135816     2.972411 -238.859104 -119.359436   267.021248
# 107977    328.405783     2.971722 -238.821049 -119.412201   267.010800
# 107978    328.567481     2.970674 -238.705051 -119.454987   266.926198
# 107979    332.154544     2.963987 -238.796696 -119.034027   266.820092
# 107980    332.425243     2.963434 -235.966007 -119.114411   264.325934
#
#         tail_theta  spine_adj_x  spine_adj_y  spine_radius  spine_theta
# 107976    2.678180  -279.214146   -79.387879    290.280854     2.864577
# 107977    2.677939  -279.334843   -79.478913    290.421852     2.864389
# 107978    2.677602  -279.346012   -79.621582    290.471670     2.863927
# 107979    2.679166  -279.450230   -83.259400    291.589709     2.852027
# 107980    2.674117  -279.598667   -83.370545    291.763710     2.851807
#
# [5 rows x 38 columns]
#
# coords is {'mouth': array([[-331.21162791,  -38.83126862],
#        [-331.49267954,  -39.09594758],
#        [-331.70735544,  -39.42077668],
#        ...,
#        [-370.26015085,  -97.15087922],
#        [-371.12004465,  -93.11145051],
#        [-371.80194468,  -88.7149051 ]], shape=(35992, 2)), 'L_eye': array([[-314.63263315,  -42.80609162],
#        [-314.86499399,  -43.06097443],
#        [-315.02862925,  -43.34832795],
#        ...,
#        [-353.83749766,  -97.62817414],
#        [-354.5839271 ,  -96.49792512],
#        [-355.29425425,  -92.31954987]], shape=(35992, 2)), 'R_eye': array([[-323.45099253,  -55.25006135],
#        [-323.67894358,  -55.51846345],
#        [-323.77989573,  -55.88531525],
#        ...,
#        [-362.00568003, -113.14044221],
#        [-362.78915781, -109.22833283],
#        [-366.57788462, -107.77182038]], shape=(35992, 2)), 'spine': array([[-279.21414561,  -79.38787873],
#        [-279.33484263,  -79.47891267],
#        [-279.34601206,  -79.62158234],
#        ...,
#        [-314.12533945, -129.61138947],
#        [-314.64081187, -129.05767853],
#        [-319.26480479, -128.45288117]], shape=(35992, 2)), 'tail': array([[-238.8591041 , -119.35943635],
#        [-238.82104868, -119.41220124],
#        [-238.70505137, -119.45498688],
#        ...,
#        [-266.51178354, -161.85369904],
#        [-270.19253916, -160.73645051],
#        [-271.14050669, -156.22448762]], shape=(35992, 2))}
#   mouth: (35992, 2), first three rows (i.e., frames): [[-331.21162791  -38.83126862]
#  [-331.49267954  -39.09594758]
#  [-331.70735544  -39.42077668]]
#   L_eye: (35992, 2), first three rows (i.e., frames): [[-314.63263315  -42.80609162]
#  [-314.86499399  -43.06097443]
#  [-315.02862925  -43.34832795]]
#   R_eye: (35992, 2), first three rows (i.e., frames): [[-323.45099253  -55.25006135]
#  [-323.67894358  -55.51846345]
#  [-323.77989573  -55.88531525]]
#   spine: (35992, 2), first three rows (i.e., frames): [[-279.21414561  -79.38787873]
#  [-279.33484263  -79.47891267]
#  [-279.34601206  -79.62158234]]
#   tail: (35992, 2), first three rows (i.e., frames): [[-238.8591041  -119.35943635]
#  [-238.82104868 -119.41220124]
#  [-238.70505137 -119.45498688]]
#
#  track_data length is 35992
#   first 5 lengths for track track_3: [np.float64(193.3217684857581), np.float64(193.4489384740434), np.float64(193.5739754793267), np.float64(198.19878776632197), np.float64(204.2611835790778)]
# <class 'pandas.core.frame.DataFrame'>
# Index(['track', 'average_length'], dtype='object')
#
# Total dist traveled and estimated size for each track:
#           fish_id  group_size group_id    track  total_distance  \
# 0   t1_1s_track_0           1    t1_1s  track_0    19357.097905
# 1   t2_1s_track_0           1    t2_1s  track_0     4335.536650
# 2   t3_1s_track_0           1    t3_1s  track_0     3150.826006
# 3   t4_1s_track_0           1    t4_1s  track_0    65748.089018
# 4   t5_1s_track_0           1    t5_1s  track_0     4759.021267
# ..            ...         ...      ...      ...             ...
# 75  t7_4s_track_3           4    t7_4s  track_3    57889.751256
# 76  t8_4s_track_0           4    t8_4s  track_0   143238.766287
# 77  t8_4s_track_1           4    t8_4s  track_1   116870.660146
# 78  t8_4s_track_2           4    t8_4s  track_2   130933.756257
# 79  t8_4s_track_3           4    t8_4s  track_3   151127.450794
#
#     estimated_size
# 0       231.832164
# 1       170.134729
# 2       172.699677
# 3       296.267521
# 4       199.393761
# ..             ...
# 75      208.189548
# 76      301.903067
# 77      179.238805
# 78      238.187123
# 79      197.703729
#
# [80 rows x 6 columns]
